# %% [markdown]
# **Python OOPs Questions**

# %% [markdown]
# 1 What is Object-Oriented Programming (OOP)?
#
# Ans - OOP is a way of programming where we model real-world things as objects that contain data and actions.

# %% [markdown]
# 2. What is a class in OOP?
#
# Ans - A class is a blueprint that defines properties and behaviors of objects.

# %% [markdown]
# 3. What is an object in OOP?
#
# Ans - An object in OOP is a real-world instance of a class. It represents something that has data (attributes) and can perform actions (methods).

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?
#
# Ans - Abstraction means hiding unnecessary details and showing only what the user needs.
#
# -> Encapsulation means wrapping data and methods together and protecting data from outside access.

# %% [markdown]
# 5. What are dunder methods in Python?
#
# Ans - Dunder methods are special methods in Python whose names start and end with double underscores. and Dunder methods allow you to define how objects behave with built-in Python operations.

# %% [markdown]
# 6.  Explain the concept of inheritance in OOP.
#
# Ans - Inherhitance mainly used to reuse code, hierarchy, and extensibility. Inheritance is an OOP concept where a child class acquires properties and methods of a parent class.

# %% [markdown]
# 7. What is polymorphism in OOP?
#
# Ans - Polymorphism means many form and in oop it allows the same method name to behave differently depending on the object that is calling it.

# %% [markdown]
# 8.  How is encapsulation achieved in Python?
#
# Ans - Encapsulation means binding data (variables) and methods together and restricting direct access to data. In Python, encapsulation is achieved using access control conventions (not strict enforcement like Java).

# %% [markdown]
# 9. What is a constructor in Python?
#
# Ans - A constructor in Python is a special method that is automatically called when an object is created from a class. constructor main purpose is to initialize (set up) object data.

# %% [markdown]
# 10. What are class and static methods in Python?
#
# Ans - Class methods operate on the class, while static methods are independent utility functions inside a class.

# %% [markdown]
# 11. What is method overloading in Python?
#
# Ans - Method overloading means having multiple methods with the same name but different parameters. Python does not support traditional method overloading, but similar behavior is achieved using default and variable arguments.

# %% [markdown]
# 12. What is method overriding in OOP?
#
# Ans - Method overriding happens when a child class provides its own implementation of a method that already exists in the parent class. but parents does not change the child class method.

# %% [markdown]
# 13. What is a property decorator in Python?
#
# Ans - The property decorator allows you to access a method like an attribute, while still keeping control over how the value is retrieved, validated, or modified.

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
# Ans - Polymorphism makes OOP flexible, scalable, and easy to maintain by allowing the same method to work with different object types.

# %% [markdown]
# 15. What is an abstract class in Python?
#
# Ans - An abstract class defines a template with mandatory methods that child classes must implement.

# %% [markdown]
# 16. What are the advantages of OOP?
#
# Ans - OOP improves code organization, reuse, security, and scalability, making software easier to develop and maintain.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?
#
# Ans - Instance variable - its defined inside a constructor (__init__) using self and unique to each object. instance variable is stored in the object namespace.
#
# Class Variable - In class variable defined directly inside the class, outside methods and shared by all object of the class. class variable stored in the class namespace.

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
# Ans - Multiple inheritance occurs when a child class inherits from more than one parent class. child class gets attributes and methods from all parent classes and allows combining functionality from multiple classes.

# %% [markdown]
# 19.  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
# Ans - Both mentod are dunder method in pyhton used to define how objects are represented as strings, but they serve different purposes.
#
# *>  __str__ → User-Friendly Representation and Called by print() or str().
# its Provides a readable, user-friendly description of the object, Meant for end users.
#
# *> __repr__ Developer-Friendly / Debug Representationand called by repr() or in interactive shell.its Provides official representation that ideally can recreate the object, Meant for developers/debugg.

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python?
#
# Ans - The super() function is used to call a method from a parent (base) class in a child (derived) class. It is especially important in inheritance, to reuse parent class functionality without explicitly naming the parent.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python?
#
# Ans - The __del__ method, also called a destructor, is a special method in Python that is automatically called when an object is about to be destroyed (garbage collected). It allows you to perform cleanup actions before the object is removed from memory.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
# Ans - Both @staticmethod and @classmethod are decorators used to define special kinds of methods in a class, but they differ in what they can access and how they are called.
#
# **@staticmethod**
# . Doesn’t take self or cls as the first parameter.
# . Cannot access instance variables or class variables.
# . Acts like a regular function, just lives inside a class for organization.
#
# **@classmethod**
# . Takes cls as the first parameter (refers to the class, not object).
# . Can access or modify class variables, but not instance variables.
# . Can be called using class name or object.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?
#
# Ans - Polymorphism in Python means “one interface, many implementations.”
# When combined with inheritance, it allows a child class to override a parent class method, so the same method call can behave differently depending on the object type.

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
# Ans - Method chaining is a programming technique in Python where multiple methods are called in a single statement, one after another, using the same object. Each method returns the object itself (self) so that the next method can be called. Makes code concise and readable.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?
#
# Ans - The __call__ method is a special (dunder) method that allows an object to be called like a function. By defining __call__ in a class, you can invoke the object itself with parentheses (). Makes the object behave like a callable function

# %% [markdown]
# **Practical Questions**

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"

# %%
class Animal:
    def speak(self):
        print("Generic animal sound")
class Dog(Animal):
    def speak(self):
        print("Bark!")
m = Animal()
n = Dog()

m.speak()
# Out:
# Generic animal sound

# %%
n.speak()
# Out:
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Create objects
c = Circle(5)
r = Rectangle(4, 6)

# Display areas
print("Circle area:", round(c.area(), 2))       # Rounded to 2 decimals
print("Rectangle area:", r.area())
# Out:
# Circle area: 78.54
# Rectangle area: 24

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
# Parent class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print("Vehicle type:", self.type)

# Child class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)   # Initialize parent
        self.brand = brand

    def show_brand(self):
        print("Car brand:", self.brand)

# Grandchild class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)   # Initialize parent (Car)
        self.battery = battery

    def show_battery(self):
        print("Battery capacity:", self.battery, "kWh")

# Create object
e_car = ElectricCar("Four-wheeler", "Tesla", 100)

# Access all attributes and methods
e_car.show_type()      # From Vehicle
e_car.show_brand()     # From Car
e_car.show_battery()   # From ElectricCar
# Out:
# Vehicle type: Four-wheeler
# Car brand: Tesla
# Battery capacity: 100 kWh

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
# Base class
class Bird:
    def fly(self):
        print("This bird can fly in general")

#class1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high")

#class2
class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly, it swims")

# Create objects
birds = [Sparrow(), Penguin()]

# Demonstrate polymorphism
for bird in birds:
    bird.fly()
# Out:
# Sparrow can fly high
# Penguin cannot fly, it swims

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance   # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount")
        elif amount > self.__balance:
            print("Insufficient balance")
        else:
            self.__balance -= amount
            print(f"Withdrawn: ₹{amount}")

    def check_balance(self):
        print(f"Current Balance: ₹{self.__balance}")


# Create object
account = BankAccount(1000)

# Use methods
account.deposit(500)
account.withdraw(300)
account.check_balance()

# Direct access to private variable is not allowed
# print(account.__balance)   # ❌ AttributeError
# Out:
# Deposited: ₹500
# Withdrawn: ₹300
# Current Balance: ₹1200

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Instrument is playing")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Guitar is playing strings")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Piano is playing keys")

# Demonstrate runtime polymorphism
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar is playing strings
# Piano is playing keys

# %% [markdown]
# 7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Calling methods
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# 8.  Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    total_persons = 0   # class variable

    def __init__(self, name):
        self.name = name
        Person.total_persons += 1

    @classmethod
    def get_total_persons(cls):
        return cls.total_persons


# Create objects
p1 = Person("Ankesh")
p2 = Person("Muskan")
p3 = Person("Navin")

# Get total count
print("Total persons created:", Person.get_total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Create object
f = Fraction(3, 4)

# Print object
print(f)
# Out:
# 3/4

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Vector 1 + Vector 2 =", v3)
# Out:
# Vector 1: (2, 3)
# Vector 2: (4, 5)
# Vector 1 + Vector 2 = (6, 8)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Navin", 30)

p.greet()
# Out:
# Hello, my name is Navin and I am 30 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)


s = Student("Navin", [85, 95, 78, 92])

print(f"Average grade of {s.name}: {s.average_grade():.2f}")
# Out:
# Average grade of Navin: 87.50

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rect = Rectangle()
rect.set_dimensions(5, 4)
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 20

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

        print("Employee Salary:", emp.calculate_salary())

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

        print("Manager Salary:", mgr.calculate_salary())

emp = Employee(40, 500)
mgr = Manager(40, 500, 5000)

emp.calculate_salary()
# Out:
# 20000

# %%
mgr.calculate_salary()
# Out:
# 25000

# %% [markdown]
#  15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity
        print("Product Name:", p.name)
        print("Total Price:", p.total_price())

p = Product("Laptop", 50000, 2)

p.total_price()
# Out:
# 100000

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Cow says: Moo")

class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa")

animals = [Cow(), Sheep()]

for animal in animals:
    animal.sound()
# Out:
# Cow says: Moo
# Sheep says: Baa

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"
        print(book.get_book_info())

book = Book("Atomic Habits", "James Clear", 2018)

book.get_book_info()
# Out:
# 'Title: Atomic Habits, Author: James Clear, Year: 2018'

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def show_details(self):
        print(f"Address: {self.address}, Price: ₹{self.price}")


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def show_mansion_details(self):
        print(f"Address: {self.address}, Price: ₹{self.price}, "
            f"Rooms: {self.number_of_rooms}")


house = House("Delhi", 5000000)
mansion = Mansion("Mumbai", 25000000, 12)

house.show_details()
mansion.show_mansion_details()
# Out:
# Address: Delhi, Price: ₹5000000
# Address: Mumbai, Price: ₹25000000, Rooms: 12
